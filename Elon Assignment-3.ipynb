# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor

# %%
data = pd.read_csv("C:/Users/elon6/Desktop/data/mnist.csv")

# %%
x = data.iloc[:,1:]
y = data.iloc[:,:1]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# ### creating the models

# %%
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
lg = LogisticRegression()

# %%
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
lg.fit(x_train,y_train)
predict_dr = dt.predict(x_test)
predictionsr = rf.predict(x_test)
predictionsl = lg.predict(x_test)
# Out:
# C:\Users\elon6\AppData\Local\Temp\ipykernel_6832\4222069298.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x_train,y_train)
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
accuracy = accuracy_score(y_test, predict_dr)
print('accuracy: ', accuracy)
recall = recall_score(y_test, predict_dr, average = 'macro')
print('recall: ', recall)
precision = precision_score(y_test, predict_dr, average = 'macro')
print('precision: ', precision)
f1 = f1_score(y_test, predict_dr, average = 'macro')
print('f1:', f1)
# Out:
# accuracy:  0.8692857142857143
# recall:  0.86690789144852
# precision:  0.867145668181888
# f1: 0.8669538741124381

# %%
scores = cross_val_score(dt, x, y, cv=5, scoring='neg_mean_squared_error')

#Print the mean and standard deviation of the scores
print("Mean MSE:", -scores.mean())
print("Std MSE:", scores.std())
# Out:
# Mean MSE: 2.1711285367322155
# Std MSE: 0.09057449635821539

# %%
accuracyr = accuracy_score(y_test, predictionsr)
print('accuracy: ', accuracyr)
recallr = recall_score(y_test, predictionsr, average = 'macro')
print('recall: ', recallr)
precisionr = precision_score(y_test, predictionsr, average = 'macro')
print('precision: ', precisionr)
f1r = f1_score(y_test, predictionsr, average = 'macro')
print('f1: ', f1r)
# Out:
# accuracy:  0.9673333333333334
# recall:  0.9670259199306482
# precision:  0.9670591461555468
# f1:  0.9670229345822842

# %%
accuracyl = accuracy_score(y_test, predictionsl)
print('accuracy: ', accuracyl)
recalll = recall_score(y_test, predictionsl, average = 'macro')
print('recall: ', recalll)
precisionl = precision_score(y_test, predictionsl, average = 'macro')
print('precisionl: ', precisionl)
f1l = f1_score(y_test, predictionsl, average = 'macro')
print('f1: ', f1l)
# Out:
# accuracy:  0.9165238095238095
# recall:  0.9148774543168164
# precisionl:  0.9153137944217754
# f1:  0.914984608285257

# %% [markdown]
# ### creating the new models

# %%
#one vs one classifier
ovo_lr = OneVsOneClassifier(LogisticRegression(solver='sag'))

# %%
# one vs rest classifier
lr_ovr = LogisticRegression()
ovr = OneVsRestClassifier(lr_ovr)
ovr.fit(x_train, y_train)
y_pred_ovr = ovr.predict(x_test)
accuracy_ovr = accuracy_score(y_test, y_pred_ovr)
# Out:
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
clfl_ovo.fit(x_train, y_train)
clfl_ovr.fit(x_train, y_train)
# Out:
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
ovo_lr = OneVsOneClassifier(LogisticRegression(solver='sag'))
ovo_lr.fit(x_train, y_train)
y_pred_ovo= ovo_lr.predict(x_test)
score_ovo_lr=cross_val_score(ovo_lr,x_train,y_train,cv=KFold(n_splits=5))
lr = LogisticRegression()
lr.fit(x_train, y_train)
prob_lr = lr.predict_proba(x_test)
auc_ovo_lr = roc_auc_score(y_test, prob_lr, multi_class='ovo')
# Out:
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\elon6\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
acc_ovo = accuracy_score(y_test, y_pred_ovo)
acc_ovr = accuracy_score(y_test, y_pred_ovr)
prec_ovo = precision_score(y_test, y_pred_ovo, average='macro')
prec_ovr = precision_score(y_test, y_pred_ovr, average='macro')
recall_ovo = recall_score(y_test, y_pred_ovo, average='macro')
recall_ovr = recall_score(y_test, y_pred_ovr, average='macro')
f1_ovo = f1_score(y_test, y_pred_ovo, average='macro')
f1_ovr = f1_score(y_test, y_pred_ovr, average='macro')

# %%
auc_ovo = roc_auc_score(y_test, y_pred_ovo, average='macro')
auc_ovr = roc_auc_score(y_test, y_pred_ovr, average='macro')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6832\388440673.py in <module>
# ----> 1 auc_ovo = roc_auc_score(y_test, y_pred_ovo, average='macro')
#       2 auc_ovr = roc_auc_score(y_test, y_pred_ovr, average='macro')
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     558             )
#     559         if multi_class == "raise":
# --> 560             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     561         return _multiclass_roc_auc_score(
#     562             y_true, y_score, labels, multi_class, average, sample_weight
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %%
print(f"Accuracy (OVO): {acc_ovo}")
print(f"Accuracy (OVR): {acc_ovr}")
print(f"Precision (OVO): {prec_ovo}")
print(f"Precision (OVR): {prec_ovr}")
print(f"Recall (OVO): {recall_ovo}")
print(f"Recall (OVR): {recall_ovr}")
print(f"F1-score (OVO): {f1_ovo}")
print(f"F1-score (OVR): {f1_ovr}")
# Out:
# Accuracy (OVO): 0.9333809523809524
# Accuracy (OVR): 0.9120952380952381
# Precision (OVO): 0.9323321980052361
# Precision (OVR): 0.9106737647072507
# Recall (OVO): 0.9321590831668148
# Recall (OVR): 0.9103033017574749
# F1-score (OVO): 0.932187840367515
# F1-score (OVR): 0.9103551960238194
